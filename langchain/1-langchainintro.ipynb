# %% [markdown]
# # langchain

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

def get_weather(city: str) -> str:
   """Get the weather for a city."""
   return f"the weather in {city} is sunny."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", model_kwargs={"tools":[get_weather]},temperature=0.9)

llm

# %%
response = llm.invoke( "What is the weather in New York?" )

# %%
response
# Out:
# AIMessage(content='As an AI, I don\'t have real-time access to live weather data. My information isn\'t current.\n\nTo get the most up-to-date weather in New York, I recommend checking a reliable weather app, a weather website (like AccuWeather, The Weather Channel, or Google Weather), or simply doing a quick search online for "weather in New York."', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e5385-2b65-7093-ae4c-c34a314bc2c5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 444, 'total_tokens': 453, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 365}})
